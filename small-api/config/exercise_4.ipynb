# %%
import sqlalchemy as alch
import os 
from dotenv import load_dotenv

# Loading env variables
load_dotenv()
free_password = os.getenv("free_sql_pw")
free_user = os.getenv('free_sql_user')

# %%
import sqlalchemy as alch
import os 
from dotenv import load_dotenv

import pandas as pd

# %%
load_dotenv()
# Out:
# True

# %%
# Connection to database
dbName = "sql7600024"
connectionData=f"mysql+pymysql://{free_user}:{free_password}@sql7.freesqldatabase.com/sql7600024"
engine = alch.create_engine(connectionData)

# %%
players = pd.read_csv('../config/Data.csv')

# %%
players
# Out:
#           Country      League   Club       Player Names  Matches_Played  \
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 658   Netherlands  Eredivisie   None    Cyriel Dessers               26
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %%
players.to_sql('Players', if_exists = 'replace', con = engine, index = False)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/sqlalchemy/engine/default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     735 def do_execute(self, cursor, statement, parameters, context=None):
# --> 736     cursor.execute(statement, parameters)
#
# ...

# %%
csv_file = pd.read_csv('/Users/gerardrius/Downloads/linkedin.csv')

# %%
csv_file.to_sql('Linkedin', if_exists = 'replace', con = engine, index = False)
# Out:
# 237
