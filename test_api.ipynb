# %%
import requests

# %%
params = {
    "emp_no": 500000,
    "birth_date": "1992-06-23",
    "first_name": "Andrés",
    "last_name" : "Castro",
    "gender" : "M",
    "hire_date" : "2023-02-21"
    }

requests.post("http://127.0.0.1:7070/insert-into-employees", params = params)
# Out:
# <Response [200]>

# %%
# I will use this jupyter notebook to process a csv file I found
# It was too big so I am only taking a sample

import pandas as pd

# %%
tweets = pd.read_csv('/Users/kike/Downloads/ChatGPT.csv')
tweets.head()
# Out:
#                         Date  \
# 0  2023-01-29 15:08:03+00:00
# 1  2023-01-29 15:07:59+00:00
# 2  2023-01-29 15:07:38+00:00
# 3  2023-01-29 15:06:53+00:00
# 4  2023-01-29 15:06:18+00:00
#
#                                                Tweet  \
# 0  My hubby keeps saying I should try #ChatGPT.\n...
# 1  I've been waiting for  ChatGPT to open back up...
# 2        #ChatGPT thank u for my pitch deck bullets.
# 3  Tune in to our next Episode: Bans and regulati...
# 4  AI trainers = underpaid human annotators?!\n#C...
#
#                                                  Url            User  \
# 0  https://twitter.com/heyandriadaily/status/1619...  heyandriadaily
# 1  https://twitter.com/_doc_oc/status/16197139759...         _doc_oc
# 2  https://twitter.com/nikoonya/status/1619713889...        nikoonya
# 3  https://twitter.com/CSOonline/status/161971369...       CSOonline
# 4  https://twitter.com/OmaymaS_/status/1619713552...        OmaymaS_
#
# ...

# %%
tweets_reduced = tweets.sample(10000)
tweets_reduced.head()
# Out:
#                              Date  \
# 82028   2023-01-07 06:06:24+00:00
# 109581  2022-12-23 08:54:04+00:00
# 157876  2022-12-06 13:15:33+00:00
# 166554  2022-12-05 01:55:42+00:00
# 48060   2023-01-17 05:00:21+00:00
#
#                                                     Tweet  \
# 82028   AI will reduce man and woman to our primal nat...
# 109581  Cheating on your college essay with ChatGPT wo...
# 157876  I kneel down to ChatGPT supremacy\n\n#OpenAI #...
# 166554  I'm not surprised by "how much" #ChatGPT knows...
# 48060   #Qasim_Ali_Shah #WeStandWithBabar #chatGPT #Bo...
#
#                                                       Url             User  \
# 82028   https://twitter.com/marcus_g_relius/status/161...  marcus_g_relius
# 109581  https://twitter.com/IbrahimKShoaib/status/1606...   IbrahimKShoaib
# 157876  https://twitter.com/cryptickatz/status/1600116...      cryptickatz
# 166554  https://twitter.com/interstar/status/159958325...        interstar
# ...

# %%
tweets_reduced.to_csv('/Users/kike/Downloads/ChatGPT_reduced.csv')

# %%
import sqlalchemy as alch
import os 
from dotenv import load_dotenv
import pandas as pd

# %%
# Loading env variables
load_dotenv()
password = os.getenv("free_sql_password")
user = os.getenv("free_sql_user")

# Connection to database
dbName = "sql7600011"
connectionData=f"mysql+pymysql://{user}:{password}@sql7.freesqldatabase.com/{dbName}"
engine = alch.create_engine(connectionData)

# %%
tweets_reduced.to_sql('tweets', con=engine, if_exists='replace', index=False)
# Out:
# 10000
